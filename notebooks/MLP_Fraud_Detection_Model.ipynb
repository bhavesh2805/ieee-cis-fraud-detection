# %%
# !pip uninstall -y node2vec
# !pip install nodevectors
# Out:
# WARNING: Skipping node2vec as it is not installed.
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.4 MB/s eta 0:00:0031m21.2 MB/s eta 0:00:01
# ...
#   Created wheel for csrgraph: filename=csrgraph-0.1.28-py3-none-any.whl size=17614 sha256=2a65d536307f9cea3b74560fe168e1afb7bffaf6b03e6fd7cb697696a298259b
#   Stored in directory: /Users/bhaveshkulkarni/Library/Caches/pip/wheels/53/02/9e/d59f49d3b5cfb66422db329aacdeee16887d99ab4967b2069b
# Successfully built csrgraph
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.0.9
#     Uninstalling decorator-5.0.9:
#       Successfully uninstalled decorator-5.0.9
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.3
#     Uninstalling networkx-2.3:
#       Successfully uninstalled networkx-2.3
# ...

# %%
# !pip uninstall -y networkx node2vec nodevectors
# !pip cache purge
# !pip install --upgrade pip
# !pip install networkx==3.2.1 nodevectors
# Out:
# Found existing installation: networkx 3.2.1
# Uninstalling networkx-3.2.1:
#   Successfully uninstalled networkx-3.2.1
# WARNING: Skipping node2vec as it is not installed.
# Found existing installation: nodevectors 0.2.0
# Uninstalling nodevectors-0.2.0:
#   Successfully uninstalled nodevectors-0.2.0
# Files removed: 712
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.5 MB/s eta 0:00:0031m10.2 MB/s eta 0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# ...
# INFO: pip is looking at multiple versions of nodevectors to determine which version is compatible with other requirements. This could take a while.
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.6 MB/s  0:00:00
# ...

# %%
# !pip uninstall -y networkx
# !pip install networkx==3.2.1
# Out:
# Found existing installation: networkx 3.4.2
# Uninstalling networkx-3.4.2:
#   Successfully uninstalled networkx-3.4.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.4 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# ...
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.5.1
#     Uninstalling networkx-2.5.1:
#       Successfully uninstalled networkx-2.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nodevectors 0.2.0 requires networkx==2.5.1, but you have networkx 3.2.1 which is incompatible.
# ...

# %%
# CELL 1: Imports & settings
import os
import gc
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import precision_recall_curve, auc, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.ensemble import IsolationForest
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
from node2vec import Node2Vec

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tqdm import tqdm
sns.set(style='whitegrid')
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 15
#      13 import matplotlib.pyplot as plt
#      14 import seaborn as sns
# ---> 15 import networkx as nx
#      16 from node2vec import Node2Vec
#      18 import tensorflow as tf
#
# File /opt/anaconda3/lib/python3.12/site-packages/networkx/__init__.py:20
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# ModuleNotFoundError: No module named 'networkx.utils.backends'

# %%
# !pip uninstall -y networkx node2vec nodevectors
# !pip cache purge
# Out:
# Found existing installation: networkx 3.2.1
# Uninstalling networkx-3.2.1:
#   Successfully uninstalled networkx-3.2.1
# WARNING: Skipping node2vec as it is not installed.
# Found existing installation: nodevectors 0.1.23
# Uninstalling nodevectors-0.1.23:
#   Successfully uninstalled nodevectors-0.1.23
# Files removed: 25 (5.0 MB)

# %%
# !pip install networkx==3.2.1 nodevectors==0.2.3
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement nodevectors==0.2.3 (from versions: 0.1.6, 0.1.8, 0.1.12, 0.1.16, 0.1.17, 0.1.18, 0.1.19, 0.1.20, 0.1.22, 0.1.23, 0.2.0)
# ERROR: No matching distribution found for nodevectors==0.2.3

# %%
# !pip install networkx==3.2.1 nodevectors==0.2.0
# Out:
# ...
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# ...
# INFO: pip is looking at multiple versions of nodevectors to determine which version is compatible with other requirements. This could take a while.
# ERROR: Cannot install networkx==3.2.1 and nodevectors==0.2.0 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested networkx==3.2.1
#     nodevectors 0.2.0 depends on networkx==2.5.1
#
# Additionally, some packages in these conflicts have no matching distributions available for your environment:
#     networkx
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts

# %%
# !pip install networkx==3.2.1 nodevectors
# Out:
# ...
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached nodevectors-0.2.0-py3-none-any.whl.metadata (8.7 kB)
# ...
# INFO: pip is looking at multiple versions of nodevectors to determine which version is compatible with other requirements. This could take a while.
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.0 MB/s  0:00:00
# ...
#   Created wheel for nodevectors: filename=nodevectors-0.1.23-py3-none-any.whl size=17967 sha256=257712ee0a0d400fdbe00f81ae072e38919cea4edf6dd62f9353031bf38bf766
#   Stored in directory: /Users/bhaveshkulkarni/Library/Caches/pip/wheels/20/03/24/585b0ed2c78f5316c00e9a78065b82fdce63ae915461e9af3a
# Successfully built nodevectors
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nodevectors]
# ...

# %%
import networkx as nx
from nodevectors import Node2Vec

print("NetworkX version:", nx.__version__)
G = nx.fast_gnp_random_graph(100, 0.05, seed=42)
n2v = Node2Vec(n_components=8, walklen=5, epochs=1)
n2v.fit(G)
print("Embedding shape:", n2v.predict(G).shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 import networkx as nx
#       2 from nodevectors import Node2Vec
#       4 print("NetworkX version:", nx.__version__)
#
# File /opt/anaconda3/lib/python3.12/site-packages/networkx/__init__.py:20
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# ModuleNotFoundError: No module named 'networkx.utils.backends'

# %%
# CELL 1: Imports & settings
import os
import gc
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import precision_recall_curve, auc, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.ensemble import IsolationForest
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
from node2vec import Node2Vec

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tqdm import tqdm
sns.set(style='whitegrid')
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 15
#      13 import matplotlib.pyplot as plt
#      14 import seaborn as sns
# ---> 15 import networkx as nx
#      16 from node2vec import Node2Vec
#      18 import tensorflow as tf
#
# File /opt/anaconda3/lib/python3.12/site-packages/networkx/__init__.py:20
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# ModuleNotFoundError: No module named 'networkx.utils.backends'
